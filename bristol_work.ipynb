# %%
import pandas as pd
import geopandas as gpd

# %%
all_postcodes_centroids= pd.read_csv('/Users/gocchini/Downloads/NSPL_NOV_2022_UK/Data/NSPL_NOV_2022_UK.csv')
# Out:
# /var/folders/0f/pzhfvnbj63jg3sk3nj099q3w0000gq/T/ipykernel_31180/2875589806.py:1: DtypeWarning: Columns (31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_postcodes_centroids= pd.read_csv('/Users/gocchini/Downloads/NSPL_NOV_2022_UK/Data/NSPL_NOV_2022_UK.csv')

# %%
bristol = gpd.read_file('/Users/gocchini/Downloads/bristol/bristol.shp')

# %%
bristol
# Out:
#   objectid       lacd              lanm    area_m2   perimeter_m mi_prinx  \
# 0        1  E06000023  Bristol, City of  111597664  71682.359375     1124
#
#      shape_area   shape_lengt  \
# 0  1.115977e+08  71682.361567
#
#                                             geometry
# 0  POLYGON ((-2.64008 51.44045, -2.64000 51.44065...

# %%
bristol.plot()
# Out:
# <Axes: >
