# %%
import pandas as pd 
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point
import seaborn

# %%
df = pd.read_pickle('/Users/gocchini/Desktop/CC project/tutorial_following/results_19_05.pkl')

# %%
df
# Out:
#                    url_host_name  \
# 0               0161studio.co.uk
# 1                      017.co.uk
# 2                    01786.co.uk
# 3                    01845.co.uk
# 4                    01943.co.uk
# 5                     01am.co.uk
# 6                01capital.co.uk
# 7               01handyman.co.uk
# 8               01zero-one.co.uk
# 9              02-creative.co.uk
# 10             020services.co.uk
# 11              025nursery.co.uk
# 12                 02clean.co.uk
# 13           034motorsport.co.uk
# 14                   03now.co.uk
# 15                04energy.co.uk
# 16                    0521.co.uk
# 17            061roadrally.co.uk
# 18                 06media.co.uk
# 19                    0706.co.uk
# 20   0800-freephonenumbers.co.uk
# 21      0800carpetcleaning.co.uk
# 22          0800numbers-uk.co.uk
# 23          0800numbershop.co.uk
# 24             0800reverse.co.uk
# 25       0844accessnumbers.co.uk
# 26       blog.0800handyman.co.uk
# 27               www.01737.co.uk
# 28               www.01877.co.uk
# 29            www.01eleven.co.uk
# 30          www.01solution.co.uk
# 31                 www.01t.co.uk
# 32        www.02-contracts.co.uk
# 33         www.02-creative.co.uk
# 34                 www.020.co.uk
# 35         www.02071246666.co.uk
# 36    www.0208ableplumbing.co.uk
# 37          www.028educate.co.uk
# 38        www.03numbershop.co.uk
# 39                www.0427.co.uk
# 40             www.05group.co.uk
# 41           www.0730media.co.uk
# 42   www.07heavenmarketing.co.uk
# 43          www.0800buster.co.uk
# 44  www.0800carpetcleaning.co.uk
# 45     www.0800gasservices.co.uk
# 46      www.0800numbershop.co.uk
#
#                                     website_postcodes
# 0                                                  {}
# 1                                                  {}
# 2                                                  {}
# 3                                                  {}
# 4                                                  {}
# 5                                                  {}
# 6                                                  {}
# 7                                                  {}
# 8                       {'WC1X 8RA': 1, 'W1F 0HS': 2}
# 9                                                  {}
# 10                                      {'c981cf': 1}
# 11                                     {'SK4 3JT': 2}
# 12            {'le76Da': 1, 'es82Wi': 1, 'za55Mi': 1}
# 13                                     {'M44 5AH': 1}
# 14                                     {'S25 3QD': 1}
# 15                                                 {}
# 16                                                 {}
# 17                                                 {}
# 18                                    {'AB21 0PH': 1}
# 19                                                 {}
# 20                                     {'PH1 1LJ': 1}
# 21                                                 {}
# 22                                     {'HG5 8JP': 1}
# 23                                                 {}
# 24                                    {'EC4Y 1EU': 1}
# 25                                                 {}
# 26  {'CV4 0EH': 1, 'DC935KS': 5, 'HP440SF': 2, 'HP...
# 27  {'RH10 5HL': 1, 'RH3 7LL': 1, 'RH1 5AR': 1, 'R...
# 28                                                 {}
# 29                                      {'W6 8LH': 1}
# 30                                     {'SE9 3UL': 1}
# 31                                                 {}
# 32                                                 {}
# 33                                                 {}
# 34  {'E18 1AN': 1, 'IG8 8HD': 1, 'E18 1BD': 1, 'IG...
# 35                                                 {}
# 36                                                 {}
# 37                                                 {}
# 38  {'f64ce': 2, 'f70bb': 2, 'fb80dc': 1, 'd7d8be'...
# 39                                      {'G1 5QH': 2}
# 40                                    {'TW12 1AB': 1}
# 41                                    {'SK14 4GH': 1}
# 42                                     {'SS0 9HQ': 1}
# 43                                                 {}
# 44                                                 {}
# 45                                                 {}
# 46                                    {'LS28 6DD': 1}

# %%
pcodes = df['website_postcodes'].tolist()

# %%
pcodes
# Out:
# [{},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'WC1X 8RA': 1, 'W1F 0HS': 2},
#  {},
#  {'c981cf': 1},
#  {'SK4 3JT': 2},
#  {'le76Da': 1, 'es82Wi': 1, 'za55Mi': 1},
#  {'M44 5AH': 1},
#  {'S25 3QD': 1},
#  {},
#  {},
#  {},
#  {'AB21 0PH': 1},
#  {},
#  {'PH1 1LJ': 1},
#  {},
#  {'HG5 8JP': 1},
#  {},
#  {'EC4Y 1EU': 1},
#  {},
#  {'CV4 0EH': 1,
#   'DC935KS': 5,
#   'HP440SF': 2,
#   'HP441SF': 2,
#   'EC4A 3WU': 1,
#   'cu988bl': 1,
#   'kd211bl': 1,
#   'eu495bl': 1,
#   'oj138bl': 1,
#   'ia111bl': 2,
#   'zr394bl': 1,
#   'bp160bl': 1,
#   'ja111bl': 1,
#   'wo665bl': 2,
#   'bv516bl': 1,
#   'oh333bl': 1,
#   'cv887bl': 1,
#   'oh444bl': 1,
#   'ew915bl': 1,
#   'qe626bl': 1,
#   'jc111bl': 1,
#   'dv998bl': 1,
#   'yr777bl': 1,
#   'xq766bl': 1,
#   'gx099bl': 1,
#   'sl544bl': 1,
#   'vn655bl': 1,
#   'sj544bl': 1,
#   'md838bl': 1,
#   'nf949bl': 1,
#   'dv506bl': 1,
#   'um655bl': 1,
#   'bp261bl': 1,
#   'xm261bl': 1,
#   'sk544bl': 2,
#   'dy100bl': 1,
#   'xp665bl': 1,
#   'wp666bl': 1,
#   'ia110bl': 1,
#   'ex009bl': 1,
#   'tl544bl': 1,
#   'yr776bl': 1,
#   'ct594bl': 1,
#   'ct888bl': 1,
#   'un665bl': 1,
#   'qj443bl': 1,
#   'oh433bl': 1,
#   'xp666bl': 1,
#   'wp66bl': 1,
#   'au505bl': 1,
#   'cu999bl': 1,
#   'z777bl': 1,
#   'le221bl': 1,
#   'll365in': 1,
#   'te365in': 1,
#   'an987co': 2},
#  {'RH10 5HL': 1,
#   'RH3 7LL': 1,
#   'RH1 5AR': 1,
#   'RH3 7NB': 1,
#   'RH2 7BJ': 1,
#   'RH2 9PA': 1,
#   'RH2 7PG': 1,
#   'RH1 6SU': 1,
#   'RH1 1BP': 1,
#   'KT20 6XE': 1,
#   'RH2 0JS': 1,
#   'RH1 5YP': 1,
#   'RH2 0BB': 1,
#   'RH2 7NQ': 1,
#   'RH1 6TG': 1,
#   'RH1 6BJ': 1,
#   'RH12DE': 1,
#   'RH1 6NE': 1,
#   'RH2 9RJ': 1,
#   'RH1 3EJ': 1,
#   'RH1 1AL': 1,
#   'RH1 3QD': 1,
#   'RH2 7DZ': 1,
#   'RH2 7LB': 1,
#   'RH1 6EA': 1,
#   'RH2 8AD': 1,
#   'RH3 7LT': 1,
#   'RH1 1JB': 1,
#   'RH1 1RJ': 1,
#   'RH1 4AP': 1},
#  {},
#  {'W6 8LH': 1},
#  {'SE9 3UL': 1},
#  {},
#  {},
#  {},
#  {'E18 1AN': 1,
#   'IG8 8HD': 1,
#   'E18 1BD': 1,
#   'IG3 9NR': 1,
#   'IG1 2AG': 1,
#   'IG1 4AE': 1,
#   'IG1 1YQ': 1,
#   'IG1 4TG': 1,
#   'IG1 1TE': 1,
#   'IG1 2SD': 1,
#   'IG6 1AD': 1,
#   'IG3 9RT': 1,
#   'IG4 5JT': 1,
#   'IG2 7HH': 1,
#   'E11 2RJ': 1,
#   'W1B 3HH': 1,
#   'SM1 2SW': 1,
#   'SM1 1SH': 1,
#   'SM1 1JH': 1,
#   'SM1 4LA': 1,
#   'SM2 6JT': 1,
#   'SM6 7AH': 1,
#   'SM1 4BW': 1,
#   'SM3 8BD': 1,
#   'EC1N 8JY': 1,
#   'SG18 0JE': 1,
#   'W1W 7LT': 1,
#   'SM6 7DE': 1,
#   'KT2 6JZ': 1,
#   'GU21 5BA': 1,
#   'SE8 5NY': 1,
#   'W12 7JP': 1,
#   'EC1M 6HJ': 1,
#   'EC2Y 9AR': 1,
#   'W11 1LT': 1,
#   'EH10 4EN': 1,
#   'EC1V 2NX': 1,
#   'ME5 9LY': 1,
#   'SE8 4NT': 1,
#   'SE25 4BJ': 1,
#   'SE1 0QX': 1,
#   'SE16 3LF': 1,
#   'SE13 6ST': 1,
#   'SE19 3SB': 1,
#   'SE14 6QP': 1,
#   'WC2A 1DU': 1,
#   'W1S 2EY': 1,
#   'SW1Y 6NH': 2,
#   'N1 6HB': 1,
#   'SE17 1RW': 1,
#   'CR0 6TE': 1,
#   'W1S 3AT': 1,
#   'W1S 3PP': 1,
#   'W1S 2FD': 1,
#   'W1S 3PF': 4,
#   'WC1R 4RG': 1,
#   'EC2M 7QD': 1,
#   'SE1 8LF': 1,
#   'EC1Y 2AA': 1,
#   'W1S 3PJ': 1,
#   'W1X 1AF': 1,
#   'N1 3DW': 1,
#   'W1S 3JR': 1,
#   'W1S 2RU': 1,
#   'OX1 4BT': 1,
#   'W1S 3BG': 1,
#   'E14 9XL': 1,
#   'EC4Y 1AA': 1,
#   'BR6 6AE': 1,
#   'UB3 9AB': 1,
#   'KT3 6BG': 1,
#   'AL7 1AD': 1,
#   'KT9 1BD': 1,
#   'E17 4PJ': 1,
#   'DA1 3QE': 1,
#   'N7 9HA': 1,
#   'NW10 7LQ': 1,
#   'KT22 9RD': 1,
#   'MK5 7HP': 1,
#   'DA7 5AF': 1,
#   'IG7 6PB': 1,
#   'SW1H 0BH': 1,
#   'SW18 4SE': 1,
#   'RH12 4SE': 1,
#   'E14 3AN': 1,
#   'CR4 3BH': 1,
#   'UB4 0SL': 1,
#   'N21 1PG': 1,
#   'KT6 6AH': 1,
#   'TW1 1DQ': 1,
#   'UB7 8EW': 1,
#   'W1G 7ET': 1,
#   'W1G 6BW': 1,
#   'SW5 0TU': 1,
#   'W1U 5NY': 1,
#   'SE1 2PR': 1,
#   'W1G 8QS': 1,
#   'HA8 0AD': 1,
#   'SM3 9DW': 1,
#   'CM2 0NF': 1,
#   'RG25 3JN': 1,
#   'E15 1LN': 1,
#   'DA15 9NB': 1,
#   'DA7 6QJ': 1,
#   'DA18 4AJ': 1,
#   'DA7 4DA': 1,
#   'DA18 4AB': 1,
#   'DA6 8BP': 1,
#   'DA14 6BU': 1,
#   'DA15 8SH': 1,
#   'SE26 5AQ': 1,
#   'BR6 0QY': 1,
#   'BR6 8EZ': 1,
#   'BR1 4BY': 1,
#   'BR2 0TL': 1,
#   'BR1 1TG': 1,
#   'N21 1QX': 1,
#   'N13 5ED': 1,
#   'N13 5PD': 1,
#   'N9 7QB': 1,
#   'EN2 9EE': 1,
#   'N14 6HS': 1,
#   'E1 6JJ': 1,
#   'E2 8HT': 1,
#   'EC2A 3LQ': 1,
#   'E15 3NW': 1,
#   'N1 7SR': 1,
#   'TW1 3BE': 1,
#   'TW1 2DD': 1,
#   'SW14 7BG': 1,
#   'TW12 3XP': 1,
#   'TW2 7AD': 1,
#   'TW10 5DQ': 1,
#   'TW11 0AY': 1,
#   'RH1 3LX': 1,
#   'CR0 3NJ': 1,
#   'WC1N 3XX': 1,
#   'KT12 1AE': 1,
#   'CO1 2FP': 1,
#   'E3 2SG': 1,
#   'NW11 8EL': 1,
#   'BR5 4BQ': 1,
#   'W2 1RL': 1,
#   'GU10 2DZ': 1,
#   'E18 2NR': 1,
#   'KT2 6HJ': 1,
#   'SM7 3PP': 1,
#   'SE26 9SS': 1,
#   'SW14 7NX': 1,
#   'IG9 6AR': 1,
#   'E7 8JX': 1,
#   'HP12 3RE': 1,
#   'SL5 0DP': 2,
#   'TW20 9LF': 1,
#   'CR0 2EF': 1,
#   'SE26 5QG': 1,
#   'SW6 7DU': 1,
#   'RG31 6YN': 1,
#   'GU33 7QE': 1,
#   'SW19 2PT': 1,
#   'TW7 7HE': 1,
#   'KT2 5AA': 1,
#   'KT11 3JZ': 1,
#   'CM3 8EW': 1,
#   'RM3 8UF': 1,
#   'CR8 5JF': 1,
#   'SW1W 9BJ': 1,
#   'E14 3BD': 1,
#   'CR0 6DU': 1,
#   'SW11 6QE': 1,
#   'HA1 4JP': 1,
#   'EN8 9UD': 1,
#   'EC2A 4NE': 1,
#   'TW2 5NX': 1,
#   'TW11 0QF': 1,
#   'N1C 4AG': 1,
#   'NW1 2LH': 1,
#   'W1W 5DD': 1,
#   'E1 7LS': 1,
#   'UB9 6EJ': 1,
#   'GL10 2NZ': 1,
#   'EC1V 4PY': 1,
#   'EC4R 2SU': 1,
#   'SW15 1SP': 1,
#   'GU15 3BG': 1,
#   'BH13 7ET': 1,
#   'RG9 5NH': 1,
#   'OX29 4TP': 1,
#   'GU21 3DN': 1,
#   'W4 4PH': 1,
#   'W1 5EP': 1,
#   'NW1 4SA': 1,
#   'BH15 4GE': 1,
#   'W14 8RR': 1,
#   'NW7 2JT': 1,
#   'AL5 4TQ': 1,
#   'B97 6RB': 1,
#   'WC2N 5DU': 1,
#   'KT22 8NL': 1,
#   'GU27 3RL': 1,
#   'W1G 9EL': 1,
#   'EC2M 4YF': 1,
#   'WC1H 9LS': 1,
#   'W1J 8DH': 1,
#   'W1T 1DG': 1,
#   'EC1R 3BX': 1,
#   'EC2A 4HB': 1,
#   'EC1V 4PW': 1,
#   'N13 4BS': 1,
#   'RG21 4FF': 1,
#   'KT18 7DJ': 1,
#   'EC4A 1LD': 1,
#   'E12 6PH': 1,
#   'BR1 1SD': 1,
#   'WD6 1NA': 1,
#   'BR5 2AN': 1,
#   'RG23 7EH': 1,
#   'NW7 3LL': 1,
#   'EC1A 7EB': 1,
#   'TW2 7LD': 1,
#   'N8 9DE': 1,
#   'SW15 5RW': 1,
#   'SE1 1TL': 1,
#   'SW17 9NT': 1,
#   'SW19 5EE': 1,
#   'AB51 4FR': 1,
#   'N5 1QJ': 2,
#   'SW4 0JA': 1,
#   'LD3 7HQ': 1,
#   'SW7 1EX': 1,
#   'NR16 2AD': 1,
#   'LD1 5TL': 1,
#   'EC1A 9LH': 1,
#   'KT8 9EU': 1,
#   'BN27 4EF': 1,
#   'NW7 1LB': 1,
#   'SW11 4NP': 1,
#   'RG25 3DR': 1,
#   'SW1W 8LP': 1,
#   'DE24 8SW': 1,
#   'SW8 3QR': 1,
#   'KT10 0PD': 1,
#   'W11 4UA': 1,
#   'W1W 7QJ': 1,
#   'W1U 7HG': 1,
#   'W1U 6BZ': 1,
#   'E9 5EN': 1,
#   'NW3 1QS': 1,
#   'E8 4PH': 1,
#   'SE22 9EU': 1,
#   'E3 2PA': 1,
#   'SW1X 9HL': 1,
#   'SW20 0AX': 1,
#   'SE5 7EW': 1,
#   'W11 2AD': 1,
#   'SE24 0PA': 1,
#   'E1 6QR': 1,
#   'NW10 7UD': 1,
#   'W1D 4RF': 1,
#   'W1U 1DS': 1,
#   'SW4 9DW': 1,
#   'N1 4NH': 1,
#   'TW10 7AG': 1,
#   'W1U 2QF': 1,
#   'W1D 4TY': 1,
#   'SE1 8TW': 1,
#   'NW1 8EH': 1,
#   'SW1W 9QD': 1,
#   'E8 3DL': 1,
#   'E2 7DP': 1,
#   'N2 0SZ': 1,
#   'E8 4EA': 1,
#   'SW5 9JA': 1,
#   'SE25 5AH': 1,
#   'W1A 1ER': 1,
#   'WC2H 7AN': 1,
#   'SW19 2RD': 1,
#   'SW1W 8BP': 1,
#   'W9 2DG': 1,
#   'SE1 7LD': 1,
#   'SW2 2DA': 1,
#   'W1U 2DX': 1,
#   'E9 5DF': 1,
#   'SW11 3RF': 1,
#   'E4 7BU': 1,
#   'E3 2SJ': 1,
#   'RM8 3PA': 1,
#   'E10 7JG': 1,
#   'HP3 9PF': 1,
#   'BR7 5DW': 1,
#   'RG18 4LP': 1,
#   'E3 3ND': 1,
#   'SP5 4ND': 1,
#   'N4 3QX': 1,
#   'PR7 5DH': 1,
#   'W10 6BL': 1,
#   'ML3 8TD': 1,
#   'KT6 4PJ': 1,
#   'SE23 1BX': 1,
#   'HP7 0HE': 1,
#   'SO15 0JX': 1,
#   'CM11 2UJ': 1,
#   'CO6 1LJ': 1,
#   'RG1 8AN': 1,
#   'NW1 9EU': 1,
#   'BD20 0DE': 1,
#   'CM2 6NX': 1,
#   'TW19 5JQ': 1,
#   'SW1V 3JY': 1,
#   'RG8 7DA': 1,
#   'N1 8JX': 1,
#   'SA62 6SA': 1,
#   'N17 0XD': 1,
#   'UB6 7PQ': 1,
#   'CO15 5SP': 1,
#   'EN9 1AB': 1,
#   'TW17 8NS': 1,
#   'IG11 7GQ': 1,
#   'SE2 9TU': 1,
#   'E1W 3TD': 1,
#   'GU1 1LW': 1,
#   'BS11 8DE': 1,
#   'NW10 7BQ': 1,
#   'WD18 9RS': 2,
#   'CM2 0PP': 1,
#   'SO20 6EX': 1,
#   'BS11 0YB': 1,
#   'E11 1JL': 1,
#   'TW8 8EF': 1,
#   'IP11 4HF': 1,
#   'HU3 1AB': 1,
#   'NW2 7JP': 1,
#   'SO14 3PX': 1,
#   'MK14 5BP': 1,
#   'W1U 6RT': 1,
#   'GU24 8NE': 1,
#   'N13 5DB': 1,
#   'WD17 4PA': 1,
#   'SG14 1BP': 1,
#   'HA3 9RD': 1,
#   'E1 5DQ': 1,
#   'N18 3QX': 1,
#   'RG24 9NY': 1,
#   'KT15 1AR': 1,
#   'IG11 0DS': 1,
#   'BR8 7ED': 1,
#   'GU29 9DD': 1,
#   'KT6 5AA': 1,
#   'RM10 7LB': 1,
#   'N2 0LX': 1,
#   'SW19 1AA': 1,
#   'SM6 7BJ': 1,
#   'UB3 1JD': 1,
#   'HA2 6EA': 1,
#   'WC2R 0JJ': 1,
#   'CM14 4GD': 1,
#   'CO1 1UX': 1,
#   'RG7 4PW': 1,
#   'IG1 3TY': 1,
#   'CR0 4UB': 1,
#   'SW1A 1AA': 1,
#   'E15 3DU': 1,
#   'RM13 7QT': 1,
#   'WD19 7BY': 1,
#   'SW6 3NG': 1,
#   'HP22 5AH': 1,
#   'TW13 7EQ': 1,
#   'NW4 3LP': 1,
#   'CR0 3RG': 1,
#   'BR3 6RH': 2,
#   'PE3 7PN': 1,
#   'KT12 1AT': 1,
#   'DA14 5BZ': 1,
#   'RH20 3DD': 1,
#   'KT16 0NZ': 1,
#   'SW7 5QJ': 1,
#   'TW15 1AX': 1,
#   'TW8 9DD': 1,
#   'SE13 7UQ': 1,
#   'E17 5DT': 1,
#   'SW18 2HZ': 1,
#   'SW14 8LN': 1,
#   'NW1 1LW': 1,
#   'SW18 5HT': 1,
#   'W1D1BS': 1,
#   'KT8 9BP': 1,
#   'CR0 1BE': 1,
#   'W4 5PY': 1,
#   'SW7 3TD': 1,
#   'KT17 1DH': 1,
#   'GU8 5AU': 1,
#   'S20 3FG': 1,
#   'SW14 8HY': 1,
#   'AL4 0NF': 1,
#   'N1 9UZ': 1,
#   'GU6 8TB': 1,
#   'SW17 0NP': 1,
#   'NW1 3AR': 1,
#   'SW7 5NR': 2,
#   'E3 2JG': 1,
#   'N1 9AG': 1,
#   'E1 6EU': 1,
#   'SW10 0ED': 1,
#   'EN11 0DE': 1,
#   'SG6 1HP': 1,
#   'WD7 9AG': 1,
#   'WD18 9TS': 1,
#   'CM23 3LJ': 1,
#   'AL1 1LJ': 1,
#   'TN24 8DX': 2,
#   'CT1 2BB': 1,
#   'TN1 2EY': 1,
#   'ME20 6SB': 1,
#   'DA1 2TW': 1,
#   'ME10 3EE': 1,
#   'ME4 4TY': 1,
#   'DA14 5HS': 1,
#   'TN23 1EH': 1,
#   'BR3 4SZ': 1,
#   'TN12 6BE': 1,
#   'TN2 3EH': 1,
#   'CT5 3PS': 1,
#   'DA11 0SD': 1,
#   'HA8 7EF': 1,
#   'TW7 6ER': 1,
#   'TW16 7BQ': 1,
#   'UB5 5QQ': 1,
#   'HA96LL': 1,
#   'TW14 9AD': 1,
#   'TW7 4PU': 1,
#   'TW8 8LR': 1,
#   'TW7 6NL': 1,
#   'HA9 7ND': 1,
#   'UB6 0AA': 1,
#   'CR2 0BS': 1,
#   'GU24 9DB': 1,
#   'GU9 9LS': 1,
#   'KT22 7SU': 1,
#   'GU1 4JJ': 1,
#   'GU21 6LY': 1,
#   'GU7 1NP': 1,
#   'GU25 4JF': 1,
#   'GU15 3DF': 1,
#   'BN21 3RL': 1,
#   'SL4 5AN': 1,
#   'BN3 5LP': 1,
#   'CF632AW': 1,
#   'CM16 4AE': 1,
#   'BR4 0RH': 1,
#   'W1K 6LN': 1,
#   'NN3 6AQ': 1,
#   'SS156PX': 1,
#   'SE16 3RA': 1,
#   'E1 1DU': 1,
#   'BR3 3QS': 1,
#   'OX29 0YG': 1,
#   'CR0 6RG': 1,
#   'CR0 3EB': 1,
#   'NN3 6QF': 1,
#   'EN3 7QN': 1,
#   'SK7 2BE': 1,
#   'IG10 1LH': 1,
#   'E4 7RG': 1,
#   'E11 3AY': 1,
#   'E4 8JR': 1,
#   'SE16 2JN': 1,
#   'CO4 5NE': 1,
#   'SE14 5XA': 1,
#   'E12 5DA': 1,
#   'IG8 0BF': 1,
#   'KT6 6QL': 1,
#   'TW10 6HR': 1,
#   'CR0 5NS': 2,
#   'KT3 6AG': 1,
#   'CR8 3DB': 1,
#   'SW19 8LR': 1,
#   'KT2 7LX': 1,
#   'SW4 7JR': 1,
#   'SW15 2UQ': 1,
#   'KT6 6QR': 1,
#   'CR0 5PH': 1,
#   'KT6 6QW': 1,
#   'SW16 2JP': 1,
#   'CR2 7DY': 1,
#   'SE25 5NQ': 1,
#   'SW11 4NN': 1,
#   'SE9 4RT': 1,
#   'EC1R 0EA': 1,
#   'EC4Y 8AU': 1,
#   'SE1 3UW': 1,
#   'SW7 2AP': 2,
#   'NW1 7AY': 1,
#   'WC2N 4JJ': 1,
#   'SW1P 3PA': 1,
#   'WC2N 5DN': 1,
#   'HA9 0AA': 1,
#   'EC3N 4AB': 1,
#   'SE1 9DA': 1,
#   'WC2N 4JL': 2,
#   'SW3 6NH': 1,
#   'WC2N 4JH': 1,
#   'EC1A 9DS': 1,
#   'EC4A 3AB': 1,
#   'EC4Y 7BL': 1,
#   'SW1E 6HQ': 1,
#   'SW1P 1QW': 1,
#   'WC2A 1AA': 1,
#   'SW1W 9AL': 1,
#   'W1J 9LL': 2,
#   'EC4M 8AD': 1,
#   'SW1X 9BZ': 1,
#   'W4 1TT': 1,
#   'SE1 7AB': 1,
#   'TW20 0EX': 1,
#   'TW10 7HT': 1,
#   'KT5 9NN': 1,
#   'N22 7BN': 1,
#   'SS2 6EL': 1,
#   'SW8 1SQ': 1,
#   'NW6 1SE': 1,
#   'W1K 2RA': 1,
#   'TW3 3UH': 1,
#   'TW13NJ': 1,
#   'W3 0UE': 1,
#   'SE19 2EZ': 1,
#   'TW15 1RP': 1,
#   'E2 6QF': 1,
#   'SW6 2AD': 1,
#   'SW6 2DZ': 1,
#   'RG26 5AG': 1,
#   'E4 8QF': 1,
#   'TW10 7NF': 1,
#   'SW6 4RB': 1,
#   'W1J 8EH': 1,
#   'W1J 7SA': 1,
#   'W1J 9BS': 1,
#   'W1K 1ND': 1,
#   'LU4 0JB': 1,
#   'SW7 4LJ': 1,
#   'WC2H 7NA': 1,
#   'W8 5LS': 1,
#   'W1H 7AW': 1,
#   'W1D 6BL': 1,
#   'SA9 1GR': 1,
#   'SM5 4AN': 1,
#   'SG8 7BZ': 1,
#   'BS27 3EJ': 1,
#   'BR7 5NL': 1,
#   'HP14 3AH': 1,
#   'SW1V 1RB': 1,
#   'RG21 8SR': 1,
#   'SM1 1LF': 1,
#   'N1 9SQ': 1,
#   'SW1V 1EJ': 1,
#   'SW6 3JD': 1,
#   'WC2A 3PX': 1,
#   'E1 6LT': 1,
#   'HP2 7DW': 1,
#   'WC1N 3AJ': 1,
#   'SL1 2SR': 1,
#   'EC1V 2PT': 1,
#   'TW10 6RR': 1,
#   'EC1R 0BJ': 1,
#   'EC2A 4HT': 1,
#   'N1 7BJ': 1,
#   'SW8 2LN': 1,
#   'EC2M 7LS': 1,
#   'WC1N 3AX': 1,
#   'BA1 5BN': 1,
#   'SW1Y 6JE': 1,
#   'SE10 8RT': 1,
#   'EN8 9FN': 1,
#   'EC3V 1LR': 2,
#   'W2 2BS': 1,
#   'W11 3RB': 1,
#   'E15 2NH': 1,
#   'SW10 0LJ': 1,
#   'CV35 7SW': 1,
#   'PR7 1QD': 1,
#   'CR8 4AN': 1,
#   'CV34 4RA': 1,
#   'GU9 7RX': 1,
#   'SW3 2HX': 1,
#   'CM77 7YJ': 1,
#   'SW6 2EB': 1,
#   'MK3 6EB': 1,
#   'BN5 9YB': 1,
#   'EC1V 7LQ': 1,
#   'N18 3BA': 1,
#   'CB5 8HE': 1,
#   'N1 2SL': 1,
#   'DA13 0LT': 1,
#   'LL46 2UE': 1,
#   'CM6 3EY': 1,
#   'SW15 1ET': 1,
#   'TN1 1YP': 1,
#   'SW6 5VA': 1,
#   'AL5 5BZ': 1,
#   'IG1 1BA': 1,
#   'NW1 4QS': 1,
#   'SW3 5BS': 1,
#   'KT13 3DF': 1,
#   'SW6 7XF': 1,
#   'BR1 3PA': 1,
#   'SE20 7ST': 1,
#   'BR2 7EB': 1,
#   'SE4 2RS': 1,
#   'SE10 9HZ': 1,
#   'SE9 1BE': 1,
#   'SE10 9JH': 1,
#   'SE21 7BN': 1,
#   'DA5 1AB': 1,
#   'BR3 6RJ': 1,
#   'SE22 8HN': 1,
#   'BR2 7EN': 1,
#   'SW6 5RS': 1,
#   'SW11 6QB': 1,
#   'SW6 5HG': 1,
#   'SW3 2HP': 1,
#   'TW9 3QB': 1,
#   'SW11 6QN': 1,
#   'SW11 1NJ': 1,
#   'SW10 9PJ': 1,
#   'SW1X 9LP': 1,
#   'SW20 9NQ': 1,
#   'E15 1EL': 1,
#   'RM6 6JB': 1,
#   'RM10 9QH': 1,
#   'IG11 7LS': 2,
#   'RM9 5NU': 1,
#   'RM9 5AJ': 1,
#   'RM8 1JX': 2,
#   'RM9 6XW': 2,
#   'E15 4QZ': 1,
#   'RM8 1DN': 1,
#   'RM6 6SB': 1,
#   'RM8 2JR': 1,
#   'RM9 5YX': 1,
#   'LU5 4QP': 1,
#   'LU3 4BL': 1,
#   'MK40 2TU': 1,
#   'LU6 2LG': 1,
#   'LU1 3JH': 1,
#   'LU1 2SE': 1,
#   'MK41 9DQ': 1,
#   'MK42 0BX': 1,
#   'LU6 2LF': 1,
#   'MK40 2BU': 1,
#   'LU2 7UX': 1,
#   'MK40 3EA': 1,
#   'MK41 7NT': 1,
#   'BR3 3AL': 1,
#   'SE9 4QF': 1,
#   'BR6 7NQ': 1,
#   'BR7 5PS': 1,
#   'BR3 6PJ': 1,
#   'BR6 9SA': 1,
#   'BR3 3HL': 1,
#   'BR5 1LA': 1,
#   'BR4 9PS': 1,
#   'BR3 4QW': 1,
#   'BR3 4EJ': 1,
#   'BR1 2TW': 1,
#   'SE19 2BH': 1,
#   'BR3 5DE': 1,
#   'BR1 5EP': 1,
#   'PE29 3BN': 1,
#   'CB3 9ED': 1,
#   'CB2 8PX': 2,
#   'CB2 7AD': 1,
#   'CB3 0EQ': 1,
#   'CB2 1JE': 1,
#   'PE19 1RU': 1,
#   'CB1 3RJ': 1,
#   'CB4 3JZ': 1,
#   'CB2 8AG': 2,
#   'CB3 9EB': 1,
#   'CB24 3DR': 1,
#   'N10 1HS': 1,
#   'N17 9LJ': 1,
#   'N22 7XL': 2,
#   'N6 4ED': 1,
#   'N6 5HG': 1,
#   'N8 8SG': 1,
#   'N6 4NY': 1,
#   'N8 8EY': 1,
#   'N15 4RX': 1,
#   'N8 8JJ': 1,
#   'N14 7DB': 1,
#   'N15 4RB': 1,
#   'N10 3NE': 1,
#   'N8 9PP': 1,
#   'N8 8RN': 1,
#   'N10 3BP': 1,
#   'N10 3JP': 1,
#   'N11 2QG': 1,
#   'N22 6UJ': 1,
#   'N11 2QH': 1,
#   'N17 8HR': 1,
#   'N15 3AS': 1,
#   'SW2 2RL': 1,
#   'SW4 6DB': 1,
#   'SE11 5SS': 1,
#   'SW12 0AB': 2,
#   'SW16 2QB': 1,
#   'SW16 1UJ': 1,
#   'SW16 1AW': 2,
#   'SW16 2QP': 1,
#   'SW4 0QW': 1,
#   'SE1 9PX': 1,
#   'SE1 9NH': 1,
#   'SW16 1SH': 1,
#   'SW9 8BA': 1,
#   'SW2 4NX': 1,
#   'SE1 8NB': 1,
#   'SW8 2JU': 2,
#   'SW11 1HS': 1,
#   'SW2 5AP': 1,
#   'SE22 0EP': 1,
#   'SE4 1LE': 1,
#   'SE26 5EQ': 1,
#   'SE6 4TY': 1,
#   'SE26 6ET': 2,
#   'SE26 6BL': 2,
#   'SE23 3PQ': 1,
#   'SE23 3HZ': 1,
#   'SE3 9PX': 1,
#   'SE12 8UE': 1,
#   'SE26 5QX': 1,
#   'SE6 4SW': 1,
#   'SW19 8EJ': 1,
#   'CR4 4NA': 1,
#   'SW19 7ND': 1,
#   'SW20 0EP': 1,
#   'CR4 1JP': 1,
#   'SW19 4JA': 1,
#   'SW19 4TT': 3,
#   'SW19 3QB': 1,
#   'SW19 1SB': 1,
#   'SW19 7EP': 2,
#   'SW16 5HB': 1,
#   'SW19 1RY': 1,
#   'SW19 4AB': 1,
#   'SW19 4AA': 1,
#   'SW19 4NS': 2,
#   'KT3 6JB': 1,
#   'SW19 8LX': 1,
#   'SW19 2LP': 1,
#   'SM4 4EE': 1,
#   'SW20 0SQ': 1,
#   'SW19 2RR': 1,
#   'SW19 8JP': 1,
#   'SW19 1HN': 1,
#   'E4 6XU': 1,
#   'E17 3PY': 2,
#   'E17 4JF': 1,
#   'E10 7QL': 1,
#   'E17 3QN': 1,
#   'E4 8SN': 1,
#   'E10 5NF': 1,
#   'E17 4LL': 1,
#   'E4 9JG': 1,
#   'E17 5AA': 1,
#   'E10 7ES': 1,
#   'IG8 9DU': 1,
#   'BR8 7LA': 1,
#   'SE18 6ED': 1,
#   'SE18 1PP': 1,
#   'SE18 6PF': 1,
#   'DA6 8DG': 1,
#   'SE1 6BD': 1,
#   'SE10 9EH': 1,
#   'SE19 3AF': 1,
#   'SE26 4NL': 1,
#   'BR6 0PG': 1,
#   'BR4 0QG': 1,
#   'SE5 0HG': 1,
#   'BR6 0NZ': 1,
#   'BR1 1EG': 1,
#   'DA6 8AB': 1,
#   'BR1 1LT': 1,
#   'SE1 7AA': 1,
#   'DA15 7DT': 1,
#   'BR6 0NW': 1,
#   'SE12 8RW': 1,
#   'BR1 3NF': 1,
#   'BR1 1JN': 1,
#   'DA1 4HG': 1,
#   'HA5 2AF': 1,
#   'SW19 3NW': 1,
#   'WC2H 5JQ': 1,
#   'WC2H 9BP': 1,
#   'IG1 1TZ': 1,
#   'BR8 7TD': 1,
#   'EN9 1JD': 1,
#   'W13 9SJ': 1,
#   'TN2 3DH': 1,
#   'N7 9AH': 1,
#   'SW19 2RL': 1,
#   'AL9 7NY': 1,
#   'RM15 6RX': 1,
#   'HA7 4TG': 1,
#   'SW19 1LT': 1,
#   'N3 3RY': 1,
#   'SW15 2QA': 1,
#   'HA8 8JS': 1,
#   'GU1 2SG': 1,
#   'SW6 3JH': 1,
#   'E14 9XG': 1,
#   'SW1X 9AE': 1,
#   'EC2M 5TU': 1,
#   'W1G 0EB': 1,
#   'SE1 1XF': 2,
#   'W5 2PX': 1,
#   'SW1P 1NH': 1,
#   'N10 1ER': 1,
#   'SW6 4HP': 1,
#   'CR2 9EE': 2,
#   'BR7 6DB': 1,
#   'SW10 9JY': 1,
#   'EC2Y 8BH': 1,
#   'SW7 2HQ': 1,
#   'EC3V 3PF': 1,
#   'WD7 7AB': 1,
#   'SE1 8RT': 2,
#   'EC2M 4RH': 1,
#   'N1 7UP': 1,
#   'W1G 9PL': 1,
#   'KT10 9RQ': 1,
#   'N1 0NX': 1,
#   'WD6 1EH': 1,
#   'HA3 6DL': 1,
#   'CF72 8YT': 1,
#   'TW11 8RZ': 1,
#   'SA19 9DW': 1,
#   'W1S 4AY': 1,
#   'N9 9HF': 1,
#   'SW1X 7XL': 1,
#   'W1S 4HT': 1,
#   'W3 0AF': 1,
#   'EC4A 1ES': 1,
#   'EC2A 3AH': 1,
#   'SE1 1YT': 1,
#   'E2 9LQ': 1,
#   'KT6 5QQ': 1,
#   'NW1 4RY': 1,
#   'EC1Y 4SD': 1,
#   'CR2 7HJ': 1,
#   'SW6 3PR': 1,
#   'N17 8ER': 1,
#   'NW8 8QN': 1,
#   'EC1 0HX': 1,
#   'KT1 1HN': 1,
#   'EC1M 5RJ': 1,
#   'WD3 4TG': 1,
#   'TW10 6UH': 1,
#   'KT1 4AD': 1,
#   'NW1 5LR': 1,
#   'E14 5AB': 1,
#   'EC1Y 2BQ': 1,
#   'KT1 2TQ': 1,
#   'TW10 6RW': 1,
#   'MK19 6JY': 1,
#   'NE66 2LQ': 1,
#   'TD1 1NZ': 1,
#   'CM3 6EG': 1,
#   'EX39 3HN': 1,
#   'N17 9ND': 1,
#   'CB10 1PG': 1,
#   'LA9 6BW': 1,
#   'EX11 1NR': 1,
#   'PL19 8JD': 1,
#   'DL3 0UY': 1,
#   'N1 1RQ': 2,
#   'TQ9 5DA': 1,
#   'W11 2JA': 1,
#   'WC2E 8RF': 1,
#   'TF1 7ET': 1,
#   'WR8 0JH': 1,
#   'NW1 8JD': 1,
#   'CR5 3SF': 1,
#   'SW1X 7RJ': 1,
#   'SL6 9UB': 1,
#   'SG5 3RS': 1,
#   'HP5 2RS': 1,
#   'RG8 9TR': 1,
#   'SK13 8BH': 1,
#   'TN26 2DR': 1,
#   'KT2 7AF': 1,
#   'HP22 5UZ': 1,
#   'UB2 5HN': 1,
#   'N17 9AA': 1,
#   'E10 5NP': 1,
#   'WD18 0EW': 1,
#   'E11 3HU': 2,
#   'IG11 8NL': 1,
#   'CR0 3AA': 1,
#   'SM1 1EA': 1,
#   'E1 5HZ': 1,
#   'W3 9BJ': 1,
#   'E15 4BQ': 1,
#   'NW10 7SU': 1,
#   'CR0 2LX': 1,
#   'HA3 8BL': 1,
#   'SE23 1PR': 1,
#   'N3 1HF': 1,
#   'N12 0BT': 1,
#   'N7 6PZ': 1,
#   'N19 3TD': 1,
#   'N8 0QY': 1,
#   'EN1 3GN': 1,
#   'EN1 3TF': 1,
#   'N8 0EP': 1,
#   'N15 3LA': 1,
#   'N5 1AA': 1,
#   'EN2 6AR': 1,
#   'EN2 6PQ': 1,
#   'EN3 5TG': 1,
#   'EN1 3PN': 1,
#   'EN2 7JA': 1,
#   'EN2 6BN': 1,
#   'EN2 7HT': 1,
#   'E8 2JS': 1,
#   'N21 3SA': 1,
#   'EC2A 3AF': 1,
#   'N13 4PN': 1,
#   'EC2M 2EE': 1,
#   'N6 5JG': 1,
#   'EN1 1YZ': 1,
#   'N15 5LE': 1,
#   'N1 9EZ': 1,
#   'EC1M 4AJ': 1,
#   'E5 9BU': 1,
#   'EC2M 2WG': 1,
#   'CM23 2QR': 1,
#   'N1 0NU': 1,
#   'EN1 3EL': 1,
#   'CR0 3PA': 1,
#   'SM1 1BS': 1,
#   'SM2 6LE': 1,
#   'SM3 9AA': 1,
#   'CR0 1EA': 1,
#   'KT4 8HW': 1,
#   'SM7 2LJ': 1,
#   'CR4 2JA': 1,
#   'SM1 4DA': 1,
#   'CR2 6AN': 1,
#   'CR9 2UU': 1,
#   'CR9 1SD': 1,
#   'CR0 0XZ': 1,
#   'SM1 4LH': 1,
#   'CR0 1QE': 1,
#   'SM1 1DS': 1,
#   'SM1 4PL': 1,
#   'CR9 2ER': 1,
#   'SW6 1BH': 1,
#   'SW16 4TA': 1,
#   'KT5 8EZ': 1,
#   'SW15 6TD': 1,
#   'SW19 7QG': 1,
#   'SW15 6BY': 1,
#   'SW16 5AQ': 1,
#   'KT15 2EW': 1,
#   'SW16 1RW': 1,
#   'SM4 5RR': 1,
#   'GU22 9DN': 1,
#   'SM4 4NY': 1,
#   'SW6 4NF': 1,
#   'KT3 6LY': 1,
#   'SW6 5SH': 1,
#   'TW10 7YQ': 1,
#   'SW9 9NB': 1,
#   'GU16 7JQ': 1,
#   'KT2 5RZ': 1,
#   'SW3 4BL': 1,
#   'SW4 9QS': 1,
#   'KT3 4PH': 1,
#   'SW12 0JH': 1,
#   'SW3 4UD': 1,
#   'SW11 6PP': 1,
#   'SW16 6AH': 1,
#   'SW19 1PP': 1,
#   'TW2 5HP': 1,
#   'SW19 3BJ': 1,
#   'AL3 5AE': 1,
#   'N18 3PN': 1,
#   'N11 3DG': 1,
#   'EN5 5JG': 1,
#   'HA8 7JZ': 1,
#   'HA9 0NP': 1,
#   'NW10 6UA': 1,
#   'HA3 6AH': 1,
#   'HA3 7RW': 1,
#   'NW5 2DL': 1,
#   'NW6 5TJ': 1,
#   'NW1 3ER': 1,
#   'PO20 8NH': 1,
#   'RH14 9DE': 1,
#   'BN27 1AU': 1,
#   'RH13 8PB': 1,
#   ...},
#  {},
#  {},
#  {},
#  {'f64ce': 2, 'f70bb': 2, 'fb80dc': 1, 'd7d8be': 1, 'bc71aa': 1},
#  {'G1 5QH': 2},
#  {'TW12 1AB': 1},
#  {'SK14 4GH': 1},
#  {'SS0 9HQ': 1},
#  {},
#  {},
#  {},
#  {'LS28 6DD': 1}]

# %%
pcodes_list = []
for i in pcodes:
    for keys, values in i.items(): #values is needeeeeed
        pcodes_list.append(keys)

# %%
pcodes_list
# Out:
# ['WC1X 8RA',
#  'W1F 0HS',
#  'c981cf',
#  'SK4 3JT',
#  'le76Da',
#  'es82Wi',
#  'za55Mi',
#  'M44 5AH',
#  'S25 3QD',
#  'AB21 0PH',
#  'PH1 1LJ',
#  'HG5 8JP',
#  'EC4Y 1EU',
#  'CV4 0EH',
#  'DC935KS',
#  'HP440SF',
#  'HP441SF',
#  'EC4A 3WU',
#  'cu988bl',
#  'kd211bl',
#  'eu495bl',
#  'oj138bl',
#  'ia111bl',
#  'zr394bl',
#  'bp160bl',
#  'ja111bl',
#  'wo665bl',
#  'bv516bl',
#  'oh333bl',
#  'cv887bl',
#  'oh444bl',
#  'ew915bl',
#  'qe626bl',
#  'jc111bl',
#  'dv998bl',
#  'yr777bl',
#  'xq766bl',
#  'gx099bl',
#  'sl544bl',
#  'vn655bl',
#  'sj544bl',
#  'md838bl',
#  'nf949bl',
#  'dv506bl',
#  'um655bl',
#  'bp261bl',
#  'xm261bl',
#  'sk544bl',
#  'dy100bl',
#  'xp665bl',
#  'wp666bl',
#  'ia110bl',
#  'ex009bl',
#  'tl544bl',
#  'yr776bl',
#  'ct594bl',
#  'ct888bl',
#  'un665bl',
#  'qj443bl',
#  'oh433bl',
#  'xp666bl',
#  'wp66bl',
#  'au505bl',
#  'cu999bl',
#  'z777bl',
#  'le221bl',
#  'll365in',
#  'te365in',
#  'an987co',
#  'RH10 5HL',
#  'RH3 7LL',
#  'RH1 5AR',
#  'RH3 7NB',
#  'RH2 7BJ',
#  'RH2 9PA',
#  'RH2 7PG',
#  'RH1 6SU',
#  'RH1 1BP',
#  'KT20 6XE',
#  'RH2 0JS',
#  'RH1 5YP',
#  'RH2 0BB',
#  'RH2 7NQ',
#  'RH1 6TG',
#  'RH1 6BJ',
#  'RH12DE',
#  'RH1 6NE',
#  'RH2 9RJ',
#  'RH1 3EJ',
#  'RH1 1AL',
#  'RH1 3QD',
#  'RH2 7DZ',
#  'RH2 7LB',
#  'RH1 6EA',
#  'RH2 8AD',
#  'RH3 7LT',
#  'RH1 1JB',
#  'RH1 1RJ',
#  'RH1 4AP',
#  'W6 8LH',
#  'SE9 3UL',
#  'E18 1AN',
#  'IG8 8HD',
#  'E18 1BD',
#  'IG3 9NR',
#  'IG1 2AG',
#  'IG1 4AE',
#  'IG1 1YQ',
#  'IG1 4TG',
#  'IG1 1TE',
#  'IG1 2SD',
#  'IG6 1AD',
#  'IG3 9RT',
#  'IG4 5JT',
#  'IG2 7HH',
#  'E11 2RJ',
#  'W1B 3HH',
#  'SM1 2SW',
#  'SM1 1SH',
#  'SM1 1JH',
#  'SM1 4LA',
#  'SM2 6JT',
#  'SM6 7AH',
#  'SM1 4BW',
#  'SM3 8BD',
#  'EC1N 8JY',
#  'SG18 0JE',
#  'W1W 7LT',
#  'SM6 7DE',
#  'KT2 6JZ',
#  'GU21 5BA',
#  'SE8 5NY',
#  'W12 7JP',
#  'EC1M 6HJ',
#  'EC2Y 9AR',
#  'W11 1LT',
#  'EH10 4EN',
#  'EC1V 2NX',
#  'ME5 9LY',
#  'SE8 4NT',
#  'SE25 4BJ',
#  'SE1 0QX',
#  'SE16 3LF',
#  'SE13 6ST',
#  'SE19 3SB',
#  'SE14 6QP',
#  'WC2A 1DU',
#  'W1S 2EY',
#  'SW1Y 6NH',
#  'N1 6HB',
#  'SE17 1RW',
#  'CR0 6TE',
#  'W1S 3AT',
#  'W1S 3PP',
#  'W1S 2FD',
#  'W1S 3PF',
#  'WC1R 4RG',
#  'EC2M 7QD',
#  'SE1 8LF',
#  'EC1Y 2AA',
#  'W1S 3PJ',
#  'W1X 1AF',
#  'N1 3DW',
#  'W1S 3JR',
#  'W1S 2RU',
#  'OX1 4BT',
#  'W1S 3BG',
#  'E14 9XL',
#  'EC4Y 1AA',
#  'BR6 6AE',
#  'UB3 9AB',
#  'KT3 6BG',
#  'AL7 1AD',
#  'KT9 1BD',
#  'E17 4PJ',
#  'DA1 3QE',
#  'N7 9HA',
#  'NW10 7LQ',
#  'KT22 9RD',
#  'MK5 7HP',
#  'DA7 5AF',
#  'IG7 6PB',
#  'SW1H 0BH',
#  'SW18 4SE',
#  'RH12 4SE',
#  'E14 3AN',
#  'CR4 3BH',
#  'UB4 0SL',
#  'N21 1PG',
#  'KT6 6AH',
#  'TW1 1DQ',
#  'UB7 8EW',
#  'W1G 7ET',
#  'W1G 6BW',
#  'SW5 0TU',
#  'W1U 5NY',
#  'SE1 2PR',
#  'W1G 8QS',
#  'HA8 0AD',
#  'SM3 9DW',
#  'CM2 0NF',
#  'RG25 3JN',
#  'E15 1LN',
#  'DA15 9NB',
#  'DA7 6QJ',
#  'DA18 4AJ',
#  'DA7 4DA',
#  'DA18 4AB',
#  'DA6 8BP',
#  'DA14 6BU',
#  'DA15 8SH',
#  'SE26 5AQ',
#  'BR6 0QY',
#  'BR6 8EZ',
#  'BR1 4BY',
#  'BR2 0TL',
#  'BR1 1TG',
#  'N21 1QX',
#  'N13 5ED',
#  'N13 5PD',
#  'N9 7QB',
#  'EN2 9EE',
#  'N14 6HS',
#  'E1 6JJ',
#  'E2 8HT',
#  'EC2A 3LQ',
#  'E15 3NW',
#  'N1 7SR',
#  'TW1 3BE',
#  'TW1 2DD',
#  'SW14 7BG',
#  'TW12 3XP',
#  'TW2 7AD',
#  'TW10 5DQ',
#  'TW11 0AY',
#  'RH1 3LX',
#  'CR0 3NJ',
#  'WC1N 3XX',
#  'KT12 1AE',
#  'CO1 2FP',
#  'E3 2SG',
#  'NW11 8EL',
#  'BR5 4BQ',
#  'W2 1RL',
#  'GU10 2DZ',
#  'E18 2NR',
#  'KT2 6HJ',
#  'SM7 3PP',
#  'SE26 9SS',
#  'SW14 7NX',
#  'IG9 6AR',
#  'E7 8JX',
#  'HP12 3RE',
#  'SL5 0DP',
#  'TW20 9LF',
#  'CR0 2EF',
#  'SE26 5QG',
#  'SW6 7DU',
#  'RG31 6YN',
#  'GU33 7QE',
#  'SW19 2PT',
#  'TW7 7HE',
#  'KT2 5AA',
#  'KT11 3JZ',
#  'CM3 8EW',
#  'RM3 8UF',
#  'CR8 5JF',
#  'SW1W 9BJ',
#  'E14 3BD',
#  'CR0 6DU',
#  'SW11 6QE',
#  'HA1 4JP',
#  'EN8 9UD',
#  'EC2A 4NE',
#  'TW2 5NX',
#  'TW11 0QF',
#  'N1C 4AG',
#  'NW1 2LH',
#  'W1W 5DD',
#  'E1 7LS',
#  'UB9 6EJ',
#  'GL10 2NZ',
#  'EC1V 4PY',
#  'EC4R 2SU',
#  'SW15 1SP',
#  'GU15 3BG',
#  'BH13 7ET',
#  'RG9 5NH',
#  'OX29 4TP',
#  'GU21 3DN',
#  'W4 4PH',
#  'W1 5EP',
#  'NW1 4SA',
#  'BH15 4GE',
#  'W14 8RR',
#  'NW7 2JT',
#  'AL5 4TQ',
#  'B97 6RB',
#  'WC2N 5DU',
#  'KT22 8NL',
#  'GU27 3RL',
#  'W1G 9EL',
#  'EC2M 4YF',
#  'WC1H 9LS',
#  'W1J 8DH',
#  'W1T 1DG',
#  'EC1R 3BX',
#  'EC2A 4HB',
#  'EC1V 4PW',
#  'N13 4BS',
#  'RG21 4FF',
#  'KT18 7DJ',
#  'EC4A 1LD',
#  'E12 6PH',
#  'BR1 1SD',
#  'WD6 1NA',
#  'BR5 2AN',
#  'RG23 7EH',
#  'NW7 3LL',
#  'EC1A 7EB',
#  'TW2 7LD',
#  'N8 9DE',
#  'SW15 5RW',
#  'SE1 1TL',
#  'SW17 9NT',
#  'SW19 5EE',
#  'AB51 4FR',
#  'N5 1QJ',
#  'SW4 0JA',
#  'LD3 7HQ',
#  'SW7 1EX',
#  'NR16 2AD',
#  'LD1 5TL',
#  'EC1A 9LH',
#  'KT8 9EU',
#  'BN27 4EF',
#  'NW7 1LB',
#  'SW11 4NP',
#  'RG25 3DR',
#  'SW1W 8LP',
#  'DE24 8SW',
#  'SW8 3QR',
#  'KT10 0PD',
#  'W11 4UA',
#  'W1W 7QJ',
#  'W1U 7HG',
#  'W1U 6BZ',
#  'E9 5EN',
#  'NW3 1QS',
#  'E8 4PH',
#  'SE22 9EU',
#  'E3 2PA',
#  'SW1X 9HL',
#  'SW20 0AX',
#  'SE5 7EW',
#  'W11 2AD',
#  'SE24 0PA',
#  'E1 6QR',
#  'NW10 7UD',
#  'W1D 4RF',
#  'W1U 1DS',
#  'SW4 9DW',
#  'N1 4NH',
#  'TW10 7AG',
#  'W1U 2QF',
#  'W1D 4TY',
#  'SE1 8TW',
#  'NW1 8EH',
#  'SW1W 9QD',
#  'E8 3DL',
#  'E2 7DP',
#  'N2 0SZ',
#  'E8 4EA',
#  'SW5 9JA',
#  'SE25 5AH',
#  'W1A 1ER',
#  'WC2H 7AN',
#  'SW19 2RD',
#  'SW1W 8BP',
#  'W9 2DG',
#  'SE1 7LD',
#  'SW2 2DA',
#  'W1U 2DX',
#  'E9 5DF',
#  'SW11 3RF',
#  'E4 7BU',
#  'E3 2SJ',
#  'RM8 3PA',
#  'E10 7JG',
#  'HP3 9PF',
#  'BR7 5DW',
#  'RG18 4LP',
#  'E3 3ND',
#  'SP5 4ND',
#  'N4 3QX',
#  'PR7 5DH',
#  'W10 6BL',
#  'ML3 8TD',
#  'KT6 4PJ',
#  'SE23 1BX',
#  'HP7 0HE',
#  'SO15 0JX',
#  'CM11 2UJ',
#  'CO6 1LJ',
#  'RG1 8AN',
#  'NW1 9EU',
#  'BD20 0DE',
#  'CM2 6NX',
#  'TW19 5JQ',
#  'SW1V 3JY',
#  'RG8 7DA',
#  'N1 8JX',
#  'SA62 6SA',
#  'N17 0XD',
#  'UB6 7PQ',
#  'CO15 5SP',
#  'EN9 1AB',
#  'TW17 8NS',
#  'IG11 7GQ',
#  'SE2 9TU',
#  'E1W 3TD',
#  'GU1 1LW',
#  'BS11 8DE',
#  'NW10 7BQ',
#  'WD18 9RS',
#  'CM2 0PP',
#  'SO20 6EX',
#  'BS11 0YB',
#  'E11 1JL',
#  'TW8 8EF',
#  'IP11 4HF',
#  'HU3 1AB',
#  'NW2 7JP',
#  'SO14 3PX',
#  'MK14 5BP',
#  'W1U 6RT',
#  'GU24 8NE',
#  'N13 5DB',
#  'WD17 4PA',
#  'SG14 1BP',
#  'HA3 9RD',
#  'E1 5DQ',
#  'N18 3QX',
#  'RG24 9NY',
#  'KT15 1AR',
#  'IG11 0DS',
#  'BR8 7ED',
#  'GU29 9DD',
#  'KT6 5AA',
#  'RM10 7LB',
#  'N2 0LX',
#  'SW19 1AA',
#  'SM6 7BJ',
#  'UB3 1JD',
#  'HA2 6EA',
#  'WC2R 0JJ',
#  'CM14 4GD',
#  'CO1 1UX',
#  'RG7 4PW',
#  'IG1 3TY',
#  'CR0 4UB',
#  'SW1A 1AA',
#  'E15 3DU',
#  'RM13 7QT',
#  'WD19 7BY',
#  'SW6 3NG',
#  'HP22 5AH',
#  'TW13 7EQ',
#  'NW4 3LP',
#  'CR0 3RG',
#  'BR3 6RH',
#  'PE3 7PN',
#  'KT12 1AT',
#  'DA14 5BZ',
#  'RH20 3DD',
#  'KT16 0NZ',
#  'SW7 5QJ',
#  'TW15 1AX',
#  'TW8 9DD',
#  'SE13 7UQ',
#  'E17 5DT',
#  'SW18 2HZ',
#  'SW14 8LN',
#  'NW1 1LW',
#  'SW18 5HT',
#  'W1D1BS',
#  'KT8 9BP',
#  'CR0 1BE',
#  'W4 5PY',
#  'SW7 3TD',
#  'KT17 1DH',
#  'GU8 5AU',
#  'S20 3FG',
#  'SW14 8HY',
#  'AL4 0NF',
#  'N1 9UZ',
#  'GU6 8TB',
#  'SW17 0NP',
#  'NW1 3AR',
#  'SW7 5NR',
#  'E3 2JG',
#  'N1 9AG',
#  'E1 6EU',
#  'SW10 0ED',
#  'EN11 0DE',
#  'SG6 1HP',
#  'WD7 9AG',
#  'WD18 9TS',
#  'CM23 3LJ',
#  'AL1 1LJ',
#  'TN24 8DX',
#  'CT1 2BB',
#  'TN1 2EY',
#  'ME20 6SB',
#  'DA1 2TW',
#  'ME10 3EE',
#  'ME4 4TY',
#  'DA14 5HS',
#  'TN23 1EH',
#  'BR3 4SZ',
#  'TN12 6BE',
#  'TN2 3EH',
#  'CT5 3PS',
#  'DA11 0SD',
#  'HA8 7EF',
#  'TW7 6ER',
#  'TW16 7BQ',
#  'UB5 5QQ',
#  'HA96LL',
#  'TW14 9AD',
#  'TW7 4PU',
#  'TW8 8LR',
#  'TW7 6NL',
#  'HA9 7ND',
#  'UB6 0AA',
#  'CR2 0BS',
#  'GU24 9DB',
#  'GU9 9LS',
#  'KT22 7SU',
#  'GU1 4JJ',
#  'GU21 6LY',
#  'GU7 1NP',
#  'GU25 4JF',
#  'GU15 3DF',
#  'BN21 3RL',
#  'SL4 5AN',
#  'BN3 5LP',
#  'CF632AW',
#  'CM16 4AE',
#  'BR4 0RH',
#  'W1K 6LN',
#  'NN3 6AQ',
#  'SS156PX',
#  'SE16 3RA',
#  'E1 1DU',
#  'BR3 3QS',
#  'OX29 0YG',
#  'CR0 6RG',
#  'CR0 3EB',
#  'NN3 6QF',
#  'EN3 7QN',
#  'SK7 2BE',
#  'IG10 1LH',
#  'E4 7RG',
#  'E11 3AY',
#  'E4 8JR',
#  'SE16 2JN',
#  'CO4 5NE',
#  'SE14 5XA',
#  'E12 5DA',
#  'IG8 0BF',
#  'KT6 6QL',
#  'TW10 6HR',
#  'CR0 5NS',
#  'KT3 6AG',
#  'CR8 3DB',
#  'SW19 8LR',
#  'KT2 7LX',
#  'SW4 7JR',
#  'SW15 2UQ',
#  'KT6 6QR',
#  'CR0 5PH',
#  'KT6 6QW',
#  'SW16 2JP',
#  'CR2 7DY',
#  'SE25 5NQ',
#  'SW11 4NN',
#  'SE9 4RT',
#  'EC1R 0EA',
#  'EC4Y 8AU',
#  'SE1 3UW',
#  'SW7 2AP',
#  'NW1 7AY',
#  'WC2N 4JJ',
#  'SW1P 3PA',
#  'WC2N 5DN',
#  'HA9 0AA',
#  'EC3N 4AB',
#  'SE1 9DA',
#  'WC2N 4JL',
#  'SW3 6NH',
#  'WC2N 4JH',
#  'EC1A 9DS',
#  'EC4A 3AB',
#  'EC4Y 7BL',
#  'SW1E 6HQ',
#  'SW1P 1QW',
#  'WC2A 1AA',
#  'SW1W 9AL',
#  'W1J 9LL',
#  'EC4M 8AD',
#  'SW1X 9BZ',
#  'W4 1TT',
#  'SE1 7AB',
#  'TW20 0EX',
#  'TW10 7HT',
#  'KT5 9NN',
#  'N22 7BN',
#  'SS2 6EL',
#  'SW8 1SQ',
#  'NW6 1SE',
#  'W1K 2RA',
#  'TW3 3UH',
#  'TW13NJ',
#  'W3 0UE',
#  'SE19 2EZ',
#  'TW15 1RP',
#  'E2 6QF',
#  'SW6 2AD',
#  'SW6 2DZ',
#  'RG26 5AG',
#  'E4 8QF',
#  'TW10 7NF',
#  'SW6 4RB',
#  'W1J 8EH',
#  'W1J 7SA',
#  'W1J 9BS',
#  'W1K 1ND',
#  'LU4 0JB',
#  'SW7 4LJ',
#  'WC2H 7NA',
#  'W8 5LS',
#  'W1H 7AW',
#  'W1D 6BL',
#  'SA9 1GR',
#  'SM5 4AN',
#  'SG8 7BZ',
#  'BS27 3EJ',
#  'BR7 5NL',
#  'HP14 3AH',
#  'SW1V 1RB',
#  'RG21 8SR',
#  'SM1 1LF',
#  'N1 9SQ',
#  'SW1V 1EJ',
#  'SW6 3JD',
#  'WC2A 3PX',
#  'E1 6LT',
#  'HP2 7DW',
#  'WC1N 3AJ',
#  'SL1 2SR',
#  'EC1V 2PT',
#  'TW10 6RR',
#  'EC1R 0BJ',
#  'EC2A 4HT',
#  'N1 7BJ',
#  'SW8 2LN',
#  'EC2M 7LS',
#  'WC1N 3AX',
#  'BA1 5BN',
#  'SW1Y 6JE',
#  'SE10 8RT',
#  'EN8 9FN',
#  'EC3V 1LR',
#  'W2 2BS',
#  'W11 3RB',
#  'E15 2NH',
#  'SW10 0LJ',
#  'CV35 7SW',
#  'PR7 1QD',
#  'CR8 4AN',
#  'CV34 4RA',
#  'GU9 7RX',
#  'SW3 2HX',
#  'CM77 7YJ',
#  'SW6 2EB',
#  'MK3 6EB',
#  'BN5 9YB',
#  'EC1V 7LQ',
#  'N18 3BA',
#  'CB5 8HE',
#  'N1 2SL',
#  'DA13 0LT',
#  'LL46 2UE',
#  'CM6 3EY',
#  'SW15 1ET',
#  'TN1 1YP',
#  'SW6 5VA',
#  'AL5 5BZ',
#  'IG1 1BA',
#  'NW1 4QS',
#  'SW3 5BS',
#  'KT13 3DF',
#  'SW6 7XF',
#  'BR1 3PA',
#  'SE20 7ST',
#  'BR2 7EB',
#  'SE4 2RS',
#  'SE10 9HZ',
#  'SE9 1BE',
#  'SE10 9JH',
#  'SE21 7BN',
#  'DA5 1AB',
#  'BR3 6RJ',
#  'SE22 8HN',
#  'BR2 7EN',
#  'SW6 5RS',
#  'SW11 6QB',
#  'SW6 5HG',
#  'SW3 2HP',
#  'TW9 3QB',
#  'SW11 6QN',
#  'SW11 1NJ',
#  'SW10 9PJ',
#  'SW1X 9LP',
#  'SW20 9NQ',
#  'E15 1EL',
#  'RM6 6JB',
#  'RM10 9QH',
#  'IG11 7LS',
#  'RM9 5NU',
#  'RM9 5AJ',
#  'RM8 1JX',
#  'RM9 6XW',
#  'E15 4QZ',
#  'RM8 1DN',
#  'RM6 6SB',
#  'RM8 2JR',
#  'RM9 5YX',
#  'LU5 4QP',
#  'LU3 4BL',
#  'MK40 2TU',
#  'LU6 2LG',
#  'LU1 3JH',
#  'LU1 2SE',
#  'MK41 9DQ',
#  'MK42 0BX',
#  'LU6 2LF',
#  'MK40 2BU',
#  'LU2 7UX',
#  'MK40 3EA',
#  'MK41 7NT',
#  'BR3 3AL',
#  'SE9 4QF',
#  'BR6 7NQ',
#  'BR7 5PS',
#  'BR3 6PJ',
#  'BR6 9SA',
#  'BR3 3HL',
#  'BR5 1LA',
#  'BR4 9PS',
#  'BR3 4QW',
#  'BR3 4EJ',
#  'BR1 2TW',
#  'SE19 2BH',
#  'BR3 5DE',
#  'BR1 5EP',
#  'PE29 3BN',
#  'CB3 9ED',
#  'CB2 8PX',
#  'CB2 7AD',
#  'CB3 0EQ',
#  'CB2 1JE',
#  'PE19 1RU',
#  'CB1 3RJ',
#  'CB4 3JZ',
#  'CB2 8AG',
#  'CB3 9EB',
#  'CB24 3DR',
#  'N10 1HS',
#  'N17 9LJ',
#  'N22 7XL',
#  'N6 4ED',
#  'N6 5HG',
#  'N8 8SG',
#  'N6 4NY',
#  'N8 8EY',
#  'N15 4RX',
#  'N8 8JJ',
#  'N14 7DB',
#  'N15 4RB',
#  'N10 3NE',
#  'N8 9PP',
#  'N8 8RN',
#  'N10 3BP',
#  'N10 3JP',
#  'N11 2QG',
#  'N22 6UJ',
#  'N11 2QH',
#  'N17 8HR',
#  'N15 3AS',
#  'SW2 2RL',
#  'SW4 6DB',
#  'SE11 5SS',
#  'SW12 0AB',
#  'SW16 2QB',
#  'SW16 1UJ',
#  'SW16 1AW',
#  'SW16 2QP',
#  'SW4 0QW',
#  'SE1 9PX',
#  'SE1 9NH',
#  'SW16 1SH',
#  'SW9 8BA',
#  'SW2 4NX',
#  'SE1 8NB',
#  'SW8 2JU',
#  'SW11 1HS',
#  'SW2 5AP',
#  'SE22 0EP',
#  'SE4 1LE',
#  'SE26 5EQ',
#  'SE6 4TY',
#  'SE26 6ET',
#  'SE26 6BL',
#  'SE23 3PQ',
#  'SE23 3HZ',
#  'SE3 9PX',
#  'SE12 8UE',
#  'SE26 5QX',
#  'SE6 4SW',
#  'SW19 8EJ',
#  'CR4 4NA',
#  'SW19 7ND',
#  'SW20 0EP',
#  'CR4 1JP',
#  'SW19 4JA',
#  'SW19 4TT',
#  'SW19 3QB',
#  'SW19 1SB',
#  'SW19 7EP',
#  'SW16 5HB',
#  'SW19 1RY',
#  'SW19 4AB',
#  'SW19 4AA',
#  'SW19 4NS',
#  'KT3 6JB',
#  'SW19 8LX',
#  'SW19 2LP',
#  'SM4 4EE',
#  'SW20 0SQ',
#  'SW19 2RR',
#  'SW19 8JP',
#  'SW19 1HN',
#  'E4 6XU',
#  'E17 3PY',
#  'E17 4JF',
#  'E10 7QL',
#  'E17 3QN',
#  'E4 8SN',
#  'E10 5NF',
#  'E17 4LL',
#  'E4 9JG',
#  'E17 5AA',
#  'E10 7ES',
#  'IG8 9DU',
#  'BR8 7LA',
#  'SE18 6ED',
#  'SE18 1PP',
#  'SE18 6PF',
#  'DA6 8DG',
#  'SE1 6BD',
#  'SE10 9EH',
#  'SE19 3AF',
#  'SE26 4NL',
#  'BR6 0PG',
#  'BR4 0QG',
#  'SE5 0HG',
#  'BR6 0NZ',
#  'BR1 1EG',
#  'DA6 8AB',
#  'BR1 1LT',
#  'SE1 7AA',
#  'DA15 7DT',
#  'BR6 0NW',
#  'SE12 8RW',
#  'BR1 3NF',
#  'BR1 1JN',
#  'DA1 4HG',
#  'HA5 2AF',
#  'SW19 3NW',
#  'WC2H 5JQ',
#  'WC2H 9BP',
#  'IG1 1TZ',
#  'BR8 7TD',
#  'EN9 1JD',
#  'W13 9SJ',
#  'TN2 3DH',
#  'N7 9AH',
#  'SW19 2RL',
#  'AL9 7NY',
#  'RM15 6RX',
#  'HA7 4TG',
#  'SW19 1LT',
#  'N3 3RY',
#  'SW15 2QA',
#  'HA8 8JS',
#  'GU1 2SG',
#  'SW6 3JH',
#  'E14 9XG',
#  'SW1X 9AE',
#  'EC2M 5TU',
#  'W1G 0EB',
#  'SE1 1XF',
#  'W5 2PX',
#  'SW1P 1NH',
#  'N10 1ER',
#  'SW6 4HP',
#  'CR2 9EE',
#  'BR7 6DB',
#  'SW10 9JY',
#  'EC2Y 8BH',
#  'SW7 2HQ',
#  'EC3V 3PF',
#  'WD7 7AB',
#  'SE1 8RT',
#  'EC2M 4RH',
#  'N1 7UP',
#  'W1G 9PL',
#  'KT10 9RQ',
#  'N1 0NX',
#  'WD6 1EH',
#  'HA3 6DL',
#  'CF72 8YT',
#  'TW11 8RZ',
#  'SA19 9DW',
#  'W1S 4AY',
#  'N9 9HF',
#  'SW1X 7XL',
#  'W1S 4HT',
#  'W3 0AF',
#  'EC4A 1ES',
#  'EC2A 3AH',
#  'SE1 1YT',
#  'E2 9LQ',
#  'KT6 5QQ',
#  'NW1 4RY',
#  'EC1Y 4SD',
#  'CR2 7HJ',
#  'SW6 3PR',
#  'N17 8ER',
#  'NW8 8QN',
#  'EC1 0HX',
#  'KT1 1HN',
#  'EC1M 5RJ',
#  'WD3 4TG',
#  'TW10 6UH',
#  'KT1 4AD',
#  'NW1 5LR',
#  'E14 5AB',
#  'EC1Y 2BQ',
#  'KT1 2TQ',
#  'TW10 6RW',
#  'MK19 6JY',
#  'NE66 2LQ',
#  'TD1 1NZ',
#  'CM3 6EG',
#  'EX39 3HN',
#  'N17 9ND',
#  'CB10 1PG',
#  'LA9 6BW',
#  'EX11 1NR',
#  'PL19 8JD',
#  'DL3 0UY',
#  'N1 1RQ',
#  'TQ9 5DA',
#  'W11 2JA',
#  'WC2E 8RF',
#  'TF1 7ET',
#  'WR8 0JH',
#  'NW1 8JD',
#  'CR5 3SF',
#  'SW1X 7RJ',
#  'SL6 9UB',
#  'SG5 3RS',
#  'HP5 2RS',
#  'RG8 9TR',
#  'SK13 8BH',
#  'TN26 2DR',
#  'KT2 7AF',
#  'HP22 5UZ',
#  'UB2 5HN',
#  'N17 9AA',
#  'E10 5NP',
#  'WD18 0EW',
#  'E11 3HU',
#  'IG11 8NL',
#  'CR0 3AA',
#  'SM1 1EA',
#  'E1 5HZ',
#  ...]

# %%
all_postcodes_centroids= pd.read_csv('/Users/gocchini/Downloads/NSPL_NOV_2022_UK/Data/NSPL_NOV_2022_UK.csv')
# Out:
# /var/folders/0f/pzhfvnbj63jg3sk3nj099q3w0000gq/T/ipykernel_26833/2875589806.py:1: DtypeWarning: Columns (31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_postcodes_centroids= pd.read_csv('/Users/gocchini/Downloads/NSPL_NOV_2022_UK/Data/NSPL_NOV_2022_UK.csv')

# %%
centrs_df = all_postcodes_centroids[['pcd', 'lat', 'long']]

# %%
centrs_df
# Out:
#              pcd        lat      long
# 0        AB1 0AA  57.101474 -2.242851
# 1        AB1 0AB  57.102554 -2.246308
# 2        AB1 0AD  57.100556 -2.248342
# 3        AB1 0AE  57.084444 -2.255708
# 4        AB1 0AF  57.096656 -2.258102
# ...          ...        ...       ...
# 2683730  ZE3 9JW  59.873651 -1.305697
# 2683731  ZE3 9JX  59.875286 -1.307502
# 2683732  ZE3 9JY  59.891572 -1.313847
# 2683733  ZE3 9JZ  59.892392 -1.310899
# 2683734  ZE3 9XP  59.887104 -1.307578
#
# [2683735 rows x 3 columns]

# %%
centrs_df['p'] = centrs_df['pcd']
# Out:
# /var/folders/0f/pzhfvnbj63jg3sk3nj099q3w0000gq/T/ipykernel_26833/2353815916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centrs_df['p'] = centrs_df['pcd']

# %%
pcodes_df = pd.DataFrame(pcodes_list)

# %%
pcodes_df.columns = ['p']

# %%
p = pcodes_df.merge(centrs_df, right_on = 'pcd', left_on= 'p', how='right')

# %%
pc = p[p['p'].notna()]

# %%
pc
# Out:
#                p      pcd        lat      long
# 39182    AL1 1LJ  AL1 1LJ  51.749541 -0.334431
# 39200    AL1 1NG  AL1 1NG  51.750305 -0.337975
# 39345    AL1 1XB  AL1 1XB  51.735008 -0.317668
# 39513    AL1 2LP  AL1 2LP  51.734561 -0.339972
# 40461    AL1 5HH  AL1 5HH  51.750264 -0.310538
# ...          ...      ...        ...       ...
# 2577599  WD7 7AB  WD7 7AB  51.683971 -0.317752
# 2578053  WD7 9AG  WD7 9AG  51.688090 -0.295656
# 2593461  WF6 2TZ  WF6 2TZ  53.719343 -1.411309
# 2596182  WF9 3NR  WF9 3NR  53.591331 -1.307107
# 2617254  WR8 0JH  WR8 0JH  52.062395 -2.218729
#
# [2144 rows x 4 columns]

# %%
coords = pc[['lat', 'long']]

# %%
pts = coords.apply(lambda r: Point(r.long, r.lat), axis=1)

# %%
gdb = gpd.GeoDataFrame(coords.assign(geometry=pts), \
                       crs={'init' :'epsg:4326'})
# Out:
# /Users/gocchini/opt/anaconda3/envs/common_crawl/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
gdb.plot()
# Out:
# <Axes: >

# %%
xys = gdb['geometry'].apply(lambda pt: pd.Series({'x': pt.x, 'y': pt.y}))
gdb['x'] = xys['x']
gdb['y'] = xys['y']

# %% [markdown]
# # Question: what if a compamnu has loads of postcodes? All happening the same amount of times

# %%
ukk = gpd.read_file('/Users/gocchini/Downloads/GBR_adm/GBR_adm2.shp')

# %%
ukk = ukk.dissolve(by = 'TYPE_2')

# %%
ukk.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Set up figure and axes
f, ax = plt.subplots(1, figsize=(10, 10))
# Add a base layer with the LSOA geography
ukk.plot(ax = ax, color='white', edgecolor='black', linewidth=0.1)
#generate KDE
gdb.plot(ax=ax, color = 'blue', markersize = 2)
plt.show()

# %%
# Set up figure and axes
f, ax = plt.subplots(1, figsize=(10, 10))
# Add a base layer with the LSOA geography
ukk.plot(ax = ax, color='white', edgecolor='black', linewidth=0.1)
#generate KDE
seaborn.kdeplot(gdb, x = 'x', y = 'y', ax=ax, 
    n_levels=100,
    fill=True,
    alpha=0.55,
    cmap="viridis_r",
)
plt.show()
